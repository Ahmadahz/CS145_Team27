# %% [markdown]
# ## Covid Predictions with ARIMA Model (Round 2)

# %%
#import the required packages 
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
import glob

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
import pandas as pd
from pandas.tseries.offsets import *
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pmdarima import auto_arima
pd.TimeSeries = pd.Series

# %%
#Get the data
df = pd.read_csv(r'./train_round2.csv', index_col=None, header=0)

# %%
#Get the required columns
dfConf = df[['Date','Province_State','Confirmed']]
dfDeath = df[['Date','Province_State','Deaths']]

# %%
#Check the data
print(dfConf.head())
print(dfDeath.head())
# Out:
#         Date Province_State  Confirmed
# 0  4/12/2020        Alabama       3563
# 1  4/12/2020         Alaska        272
# 2  4/12/2020        Arizona       3542
# 3  4/12/2020       Arkansas       1280
# 4  4/12/2020     California      22795
#         Date Province_State  Deaths
# 0  4/12/2020        Alabama      93
# 1  4/12/2020         Alaska       8
# 2  4/12/2020        Arizona     115
# 3  4/12/2020       Arkansas      27
# 4  4/12/2020     California     640

# %%
#Remove the hours from the time column:
#dfConf['Last_Update'] = pd.to_datetime(dfConf['Last_Update']).dt.date
#dfDeath['Last_Update'] = pd.to_datetime(dfDeath['Last_Update']).dt.date

# %% [markdown]
# ### Required Functions for ARIMA and ARMA

# %%
# A function for forcasting and returning the new table
# This only work for the next 26 days

def ARMA_MODEL_FORECAST_Confirmed(ds):
    
    #Get the confimred values of the state
    ConfValue = ds.Confirmed.values
    
    #Find the time series
    timeser = pd.TimeSeries(ConfValue , index=pd.to_datetime(ds.Date))
    
    #It is a non-stationary graph so we can turn it into stationary by taking the log
    ts_log_data = np.log(timeser)
    try:
        #Use Autoregressive–moving-average model for prediction
        model = sm.tsa.ARMA(ts_log_data, order=(3, 0)).fit()
        
        #Set the starting and Ending dates
        start_date = ts_log_data.index[-1] + Day(1)
        end_date = ts_log_data.index[-1] + Day(26)
        
        #Predict the values
        y_forecast = model.predict(start_date.isoformat(), end_date.isoformat())
        
        #Return a table with the new values
        Final_Table = pd.Series(np.exp(y_forecast).values, np.arange(1, 27))
        
        return Final_Table
    
    #if there is a convergance error pass it
    except Exception:
        pass
    
def ARIMA_MODEL_FORECAST_Confirmed(ds):
    
    #Get the confimred values of the state
    ConfValue = ds.Confirmed.values
    
    #Find the time series
    timeser = pd.TimeSeries(ConfValue , index=pd.to_datetime(ds.Date))
    
    try:
        #Use Autoregressive integrated moving average model for prediction
        #Trend is not constant
        #model = sm.tsa.ARIMA(timeser,order=(0,2,1)).fit()
        model = sm.tsa.ARIMA(timeser,order=(0,2,1)).fit(transparams=False, trend='nc')
        #Set the starting and Ending dates
        start_date = timeser.index[-1] + Day(1)
        end_date = timeser.index[-1] + Day(26)
        
        #Predict the values
        y_forecast = model.predict(start_date.isoformat(),end_date.isoformat(),typ='levels')

        
        #Return a table with the new values
        Final_Table = pd.Series(y_forecast.values, np.arange(1, 27))
        
        return Final_Table
    
    #if there is a convergance error pass it
    except Exception:
        pass

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def ARMA_MODEL_FORECAST_DEATHS(ds):
    
    #Get the confimred values of the state
    DeathValue = ds.Deaths.values
    
    #Find the time series
    timeser = pd.TimeSeries(DeathValue , index=pd.to_datetime(ds.Date))
    
    #It is a non-stationary graph so we can turn it into stationary by taking the log
    ts_log_data = np.log(timeser)
    try:
        #Use Autoregressive–moving-average model for prediction
        model = sm.tsa.ARMA(ts_log_data, order=(3, 0)).fit()
        
        #Set the starting and Ending dates
        start_date = ts_log_data.index[-1] + Day(1)
        end_date = ts_log_data.index[-1] + Day(26)
        
        #Predict the values
        y_forecast = model.predict(start_date.isoformat(), end_date.isoformat())
        
        #Return a table with the new values
        Final_Table = pd.Series(np.exp(y_forecast).values, np.arange(1, 27))
        
        return Final_Table
    
    #if there is a convergance error pass it
    except Exception:
        pass
    
def ARIMA_MODEL_FORECAST_DEATHS(ds):
    
    #Get the confimred values of the state
    DeathValue = ds.Deaths.values
    
    #Find the time series
    timeser = pd.TimeSeries(DeathValue , index=pd.to_datetime(ds.Date))
    
    try:
        #Use Autoregressive integrated moving average model for prediction
        model = sm.tsa.ARIMA(timeser,order=(0,2,1)).fit()
        #model = sm.tsa.ARIMA(timeser,order=(1,2,0)).fit(transparams=False, disp=False, transparams=False, trend='nc')
        
        
        #Set the starting and Ending dates
        start_date = timeser.index[-1] + Day(1)
        end_date = timeser.index[-1] + Day(26)
        
        #Predict the values
        y_forecast = model.predict(start_date.isoformat(),end_date.isoformat(),typ='levels')

        
        #Return a table with the new values
        Final_Table = pd.Series(y_forecast.values, np.arange(1, 27))
        
        return Final_Table
    
    #if there is a convergance error pass it
    except Exception:
        pass

# %%
GroupByStateCases = dfConf.groupby('Province_State')
FinalTableCases = GroupByStateCases.apply(ARIMA_MODEL_FORECAST_Confirmed)

# %% [markdown]
# ## Number of Cases for the next 7 days:

# %%
FinalTableCases = FinalTableCases.iloc[:, : 7]
FinalTableCases
# Out:
#                            1             2             3             4  \
# Province_State
# Alabama         2.708867e+05  2.741843e+05  2.774820e+05  2.807796e+05
# Alaska          3.702704e+04  3.778308e+04  3.853912e+04  3.929515e+04
# Arizona         3.644044e+05  3.699089e+05  3.754133e+05  3.809178e+05
# Arkansas        1.715830e+05  1.737840e+05  1.759850e+05  1.781861e+05
# California      1.361117e+06  1.384293e+06  1.407468e+06  1.430644e+06
# Colorado        2.624569e+05  2.675667e+05  2.726766e+05  2.777865e+05
# Connecticut     1.295299e+05  1.313448e+05  1.331597e+05  1.349746e+05
# Delaware        3.975701e+04  4.041803e+04  4.107904e+04  4.174005e+04
# Florida         1.059442e+06  1.069246e+06  1.079050e+06  1.088854e+06
# Georgia         5.034588e+05  5.075466e+05  5.116345e+05  5.157223e+05
# Hawaii          1.885183e+04  1.896565e+04  1.907948e+04  1.919331e+04
# Idaho           1.111539e+05  1.126028e+05  1.140517e+05  1.155006e+05
# Illinois        7.901371e+05  8.002992e+05  8.104614e+05  8.206235e+05
# Indiana         3.827550e+05  3.904910e+05  3.982270e+05  4.059630e+05
# Iowa            2.455554e+05  2.477259e+05  2.498963e+05  2.520668e+05
# Kansas          1.735772e+05  1.757914e+05  1.780056e+05  1.802198e+05
# Kentucky        2.014577e+05  2.048513e+05  2.082450e+05  2.116386e+05
# Georgia         10030.756120  10078.461889  10126.219172
# Hawaii            273.135894    275.591580    278.056768
# Idaho            1101.790886   1115.906324   1130.074183
# Illinois        14897.349057  15074.787394  15252.615240
# Indiana          6571.532787   6644.935203   6718.502906
# Iowa             2885.586287   2926.757059   2968.079003
# Kansas           1908.235059   1932.964153   1957.787275
# Kentucky         2168.567788   2190.061862   2211.616108
# Louisiana        6639.340991   6657.041428   6674.552611
# Maine             245.129898    248.779052    252.435931
# Maryland         4958.191771   4985.635611   5013.014612
# Massachusetts   11116.662621  11148.145563  11179.211978
# Michigan        10936.129106  11059.052969  11181.942847
# Minnesota        4279.887902   4340.699675   4401.722845
# Mississippi      4056.212286   4077.801466   4099.439553
# Missouri         4483.760333   4525.717005   4567.808545
# Montana           787.730577    798.613291    809.541539
# Nebraska         1308.228979   1331.341408   1354.542716
# Nevada           2419.559028   2443.492109   2467.498947
# New Hampshire     578.105177    581.937365    585.773271
# New Jersey      17402.964548  17419.395192  17434.838414
# New Mexico       1898.554362   1931.026071   1963.618058
# New York        35018.278768  35028.769521  35034.871942
# North Carolina   5682.434193   5715.980245   5749.612701
# North Dakota     1083.612691   1097.909710   1112.264889
# Ohio             7290.625086   7359.971906   7429.459328
# Oklahoma         1970.140315   1989.531894   2008.977979
# Oregon           1119.906463   1138.690679   1157.542536
# Pennsylvania    11836.401794  11965.958280  12095.673477
# Rhode Island     1450.477365   1457.922670   1465.351251
# South Carolina   4627.255802   4649.501999   4671.813209
# South Dakota     1212.597136   1237.226707   1261.959658
# Tennessee        5147.398676   5196.463456   5245.723249
# Texas           23993.970360  24183.799245  24374.306401
# Utah              996.325302   1007.921258   1019.560847
# Vermont            86.599864     88.122311     89.645582
# Virginia         4308.134753   4330.397708   4352.672665
# Washington       3028.668068   3049.463505   3070.279551
# West Virginia     901.852740    916.587159    931.376202
# Wisconsin        4263.366485   4329.960822   4396.795507
# Wyoming           293.969747    299.634869    305.323716

# %%
#changing the shape of the table
part1C = FinalTableCases[1]

for i in range(7):
    if (i + 2 < 8):
        part2C = FinalTableCases[i+2]
        part1C = pd.concat([part1C, part2C], ignore_index=True)

# %%
#changing the shape of the table
part1D = FinalTableDeaths[1]

for i in range(7):
    if (i + 2 < 8):
        part2D = FinalTableDeaths[i+2]
        part1D = pd.concat([part1D, part2D], ignore_index=True)

# %%
#Round the numbers amd get the final table
data = {'ForecastID': range(0, 350 ,1), 
        'Confirmed':part1C, 
        'Deaths':part1D}
  
# Create DataFrame 
table = pd.DataFrame(data) 
table['Confirmed'] = table['Confirmed'].round(decimals=0)
table['Deaths'] = table['Deaths'].round(decimals=0)
table
# Out:
#      ForecastID  Confirmed   Deaths
# 0             0   270887.0   3911.0
# 1             1    37027.0    145.0
# 2             2   364404.0   6965.0
# 3             3   171583.0   2643.0
# 4             4  1361117.0  19962.0
# ..          ...        ...      ...
# 345         345   270680.0   4353.0
# 346         346   191211.0   3070.0
# 347         347    61818.0    931.0
# 348         348   473451.0   4397.0
# 349         349    39597.0    305.0
#
# [350 rows x 3 columns]

# %%
#Get the csv file
table.to_csv(r'./Team27.csv', index = False)
